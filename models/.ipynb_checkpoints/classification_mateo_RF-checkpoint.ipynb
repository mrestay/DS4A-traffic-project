# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score, cohen_kappa_score, classification_report , roc_curve, roc_auc_score
from sklearn.model_selection import KFold, StratifiedKFold, cross_val_score
from sklearn.utils import resample 
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
# set matplotlib defaults
# %matplotlib inline
sns.set()
plt.rcParams["figure.figsize"] = (15,6)
mpl.rc('axes', labelsize=18)
mpl.rc('xtick', labelsize=16)
mpl.rc('ytick', labelsize=16)
plt.rc('figure', titlesize=18)
plt.style.use('seaborn-darkgrid')

# %%
data_2018 = pd.read_csv("../data/dataset_2018_with_negatives.csv")
data_2019 = pd.read_csv("../data/dataset_2019_with_negatives.csv")
# Out:
# /home/matt/anaconda3/envs/ds4a-project/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3062: DtypeWarning: Columns (11,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data_2018 = data_2018[(data_2018.summary.notnull())  & (data_2018.month > 8)]

# %%
print(data_2019.shape, data_2018.shape)
# Out:
# (58133, 40) (21496, 40)

# %%
data = pd.concat([data_2018, data_2019])

# %%
data = pd.get_dummies(data, columns=['summary'])

# %%
data.drop(['year', 'precipAccumulation'], axis=1, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 79629 entries, 1428 to 58132
# Data columns (total 47 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   x                            79629 non-null  float64
#  1   y                            79629 non-null  float64
#  2   timestamp                    79629 non-null  object
#  3   date                         79629 non-null  object
#  4   month                        79629 non-null  int64
#  5   day                          79629 non-null  int64
#  6   day_of_year                  79629 non-null  int64
#  7   day_of_week                  79629 non-null  int64
#  8   hour                         79629 non-null  int64
#  9   address                      79629 non-null  object
#  10  severity                     39792 non-null  object
#  11  accident_type                39792 non-null  object
#  12  severity_numeric             39792 non-null  float64
#  13  borough                      79629 non-null  object
#  14  cluster_id                   79629 non-null  int64
#  15  sample_type                  79629 non-null  int64
#  16  borough_id                   79629 non-null  int64
#  17  area_km2                     79629 non-null  float64
#  18  population                   79629 non-null  int64
#  19  population_density           79629 non-null  float64
#  20  timestamp_darksky            79629 non-null  object
#  21  icon                         79629 non-null  object
#  22  precipIntensity              79629 non-null  float64
#  23  precipProbability            79629 non-null  float64
#  24  temperature                  79629 non-null  float64
#  25  apparentTemperature          79629 non-null  float64
#  26  dewPoint                     79629 non-null  float64
#  27  humidity                     79629 non-null  float64
#  28  windSpeed                    79629 non-null  float64
#  29  cloudCover                   79629 non-null  float64
#  30  uvIndex                      79629 non-null  float64
#  31  visibility                   79629 non-null  float64
#  32  windBearing                  79629 non-null  float64
#  33  windGust                     79629 non-null  float64
#  34  pressure                     79629 non-null  float64
#  35  precipType                   76796 non-null  object
#  36  ozone                        79629 non-null  float64
#  37  summary_Clear                79629 non-null  uint8
#  38  summary_Foggy                79629 non-null  uint8
#  39  summary_Heavy Rain           79629 non-null  uint8
#  40  summary_Light Rain           79629 non-null  uint8
#  41  summary_Mostly Cloudy        79629 non-null  uint8
#  42  summary_Overcast             79629 non-null  uint8
#  43  summary_Partly Cloudy        79629 non-null  uint8
#  44  summary_Possible Drizzle     79629 non-null  uint8
#  45  summary_Possible Light Rain  79629 non-null  uint8
#  46  summary_Rain                 79629 non-null  uint8
# dtypes: float64(19), int64(9), object(9), uint8(10)
# memory usage: 23.8+ MB

# %%
corr = data.corr()
c1 = corr.abs().unstack().round(3)
c1<1
c1[(c1<1) & (c1> 0.65)].sort_values(ascending = False)
# Out:
# month                        day_of_year                    0.997
# apparentTemperature          temperature                    0.997
# day_of_year                  month                          0.997
# temperature                  apparentTemperature            0.997
#                              uvIndex                        0.833
# uvIndex                      temperature                    0.833
# windSpeed                    windGust                       0.826
# windGust                     windSpeed                      0.826
# apparentTemperature          uvIndex                        0.824
# uvIndex                      apparentTemperature            0.824
# precipProbability            precipIntensity                0.802
# precipIntensity              precipProbability              0.802
# temperature                  hour                           0.692
# hour                         temperature                    0.692
# apparentTemperature          hour                           0.685
# hour                         apparentTemperature            0.685
# precipProbability            summary_Possible Light Rain    0.682
# summary_Possible Light Rain  precipProbability              0.682
# dewPoint                     apparentTemperature            0.654
# apparentTemperature          dewPoint                       0.654
# dtype: float64

# %%
plt.figure(figsize=(14,14))
sns.heatmap(corr.where(np.tril(np.ones(corr.shape)).astype(np.bool)), cmap='coolwarm')
plt.show()

# %% [markdown]
# ## Useful Functions

# %%
def get_df(columns):
    return data[columns]

# %%
def separate_classes(df):
    return df[df.sample_type==0], df[df.sample_type==1]

# %%
def resample_df(resample_type, df_majority, df_minority):
    if resample_type == 'up':
        # Upsample minority class
        df_minority_upsampled = resample(df_minority, replace=True, n_samples=df_majority.shape[0])        
        # Combine majority class with upsampled minority class
        df_upsampled = pd.concat([df_majority, df_minority_upsampled])
        
        return df_upsampled

    if resample_type == 'down':
        # Upsample minority class
        df_majority_undersampled = resample(df_majority, replace=False, n_samples=df_minority.shape[0])        
        # Combine majority class with upsampled minority class
        df_undersampled = pd.concat([df_minority, df_majority_undersampled])
        
        return df_undersampled

# %%
def train_test_df(df, columns):
    cols = columns
    cols.remove('sample_type')
    X = df[columns]
    y = df.sample_type
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)
    return X_train, X_test, y_train, y_test

# %%
def model_fit_predict(X_train, X_test, y_train, y_test, clf):
    categories = ['non-accident', 'accident']
    clf.fit(X_train, y_train)
    scores = cross_val_score(clf, X_train, y_train, cv=5, scoring= 'f1_weighted', n_jobs=-1)
    print('Weigthed F1 score: {:.2f} (+/- {:.3f} )'.format(scores.mean(), scores.std() * 2))

    y_pred = clf.predict(X_test)
    print('Cohen kappa score {:.4f}'.format(cohen_kappa_score(y_pred, y_test)))
    print(classification_report(y_test, y_pred,target_names=categories))

    metric_names = ['f1', 'roc_auc', 'average_precision', 'accuracy', 'precision', 'recall']
    scores_df = pd.DataFrame(index=metric_names, columns=['Random-CV', 'Stratified-CV']) # to store the scores
    cv = KFold(n_splits=3)
    scv = StratifiedKFold(n_splits=3)
    for metric in metric_names:
        score1 = cross_val_score(clf, X_train, y_train, scoring=metric, cv=cv, n_jobs=-1).mean()
        score2 = cross_val_score(clf, X_train, y_train, scoring=metric, cv=scv, n_jobs=-1).mean()
        scores_df.loc[metric] = [score1, score2]
    print(scores_df)
    y_pred_proba = clf.predict_proba(X_test)[:,1]

    return clf, y_pred, y_pred_proba

# %%
def model_plot(y_test, y_pred, y_pred_proba, model_name):
    categories = ['non-accident', 'accident']
    gs = mpl.gridspec.GridSpec(2, 2)

    plt.figure(figsize=(14,10))
    ax = plt.subplot(gs[0, 0]) # row 0, col 0
    labels = [0,1]
    cnf_mx = confusion_matrix(y_test,y_pred,labels=labels)
    ax1 = sns.heatmap(cnf_mx, cmap='coolwarm',annot=True, fmt="d")
    plt.xticks([0.5,1.5],categories, rotation=0)
    plt.yticks([0.5,1.5],categories, rotation=0)
    plt.title(f'Confusion matrix {model_name}', fontsize=18)
    plt.xlabel('Predicted label')
    plt.ylabel('True label')

    ax = plt.subplot(gs[0, 1]) # row 0, col 1
    row_sums = cnf_mx.sum(axis=1, keepdims=True)
    norm_cnf_mx = cnf_mx / row_sums
    np.fill_diagonal(norm_cnf_mx, 0)
    ax2 = sns.heatmap(norm_cnf_mx, cmap='coolwarm',annot=True, fmt=".4%")
    plt.xticks([0.5,1.5],categories, rotation=0)
    plt.yticks([0.5,1.5],categories, rotation=0)
    plt.title(f'Error matrix {model_name}', fontsize=18)
    plt.xlabel('Predicted label')

    ax = plt.subplot(gs[1, :]) # row 1, span all columns
    fpr, tpr, _ = roc_curve(y_test,  y_pred_proba)
    auc = roc_auc_score(y_test, y_pred_proba)
    # Display plot for AUC curve
    ax3 = plt.plot(fpr,tpr,label= f"{model_name}, auc={round(auc,4)}")
    ax3 = plt.plot([0, 1], [0, 1], color='darkorange', lw=2, linestyle='--')
    plt.legend(fontsize=14)
    plt.title(f"ROC cuve: {model_name}", fontsize= 18)
    plt.tight_layout()
    plt.show()

# %%
def generate_cyclical_variables(df, column, period):
    if df[column].min() != 0:
        df[f'{column}_sin'] = np.sin((df[column] - 1)*(2.*np.pi/period))
        df[f'{column}_cos'] = np.cos((df[column] - 1)*(2.*np.pi/period))
    else:
        df[f'{column}_sin'] = np.sin((df[column])*(2.*np.pi/period))
        df[f'{column}_cos'] = np.cos((df[column])*(2.*np.pi/period))

    return df

# %%
generate_cyclical_variables(data, 'hour', 24)
generate_cyclical_variables(data, 'day_of_week', 7)
generate_cyclical_variables(data, 'month', 12)
generate_cyclical_variables(data, 'day_of_year', 365)
# Out:
#                x         y            timestamp                 date  month  \
# 1428  -74.154268  4.622942  2018-09-14 14:30:00           2018-09-14      9
# 1429  -74.051403  4.722273  2018-09-29 15:55:00           2018-09-29      9
# 1430  -74.094861  4.570288  2018-10-03 10:30:00           2018-10-03     10
# 1431  -74.088976  4.720519  2018-10-04 11:30:00           2018-10-04     10
# 1432  -74.072980  4.688847  2018-10-04 11:50:00           2018-10-04     10
# ...          ...       ...                  ...                  ...    ...
# 58128 -74.135687  4.580801  2019-12-03 16:00:00  2019-12-03 00:00:00     12
# 58129 -74.084275  4.590371  2019-01-12 04:00:00  2019-01-12 00:00:00      1
# 58130 -74.097752  4.619585  2019-10-04 16:00:00  2019-10-04 00:00:00     10
# 58131 -74.174217  4.576242  2019-12-20 19:00:00  2019-12-20 00:00:00     12
# 58132 -74.066859  4.636431  2019-12-21 09:00:00  2019-12-21 00:00:00     12
#
#        day  day_of_year  day_of_week  hour                      address  ...  \
# 1428    14          257            4    14            KR 78K-CL 38 S 26  ...
# 1429    29          272            5    15              AK 45-CL 137 02  ...
# 1430     3          276            2    10               KR 7-CL 26 S 2  ...
# 1431     4          277            3    11               AK 89-CL 128 2  ...
# 1432     4          277            3    11               KR 68-CL 98A 2  ...
# ...    ...          ...          ...   ...                          ...  ...
# 58128    3          337            1    16             KR 28-DG 52B S 2  ...
# 58129   12           12            5     4               KR 10-CL 1B 02  ...
# 58130    4          277            4    16               CL 13-KR 37 35  ...
# 58131   20          354            4    19            KR 75-CL 75D S 02  ...
# 58132   21          355            5     9  AV AVENIDA CARACAS-CL 49 02  ...
#
#       summary_Possible Light Rain summary_Rain  hour_sin  hour_cos  \
# 1428                            0            0 -0.500000 -0.866025
# 1429                            0            0 -0.707107 -0.707107
# 1430                            0            0  0.500000 -0.866025
# 1431                            0            0  0.258819 -0.965926
# 1432                            0            0  0.258819 -0.965926
# ...                           ...          ...       ...       ...
# 58128                           0            0 -0.866025 -0.500000
# 58129                           1            0  0.866025  0.500000
# 58130                           0            0 -0.866025 -0.500000
# 58131                           1            0 -0.965926  0.258819
# 58132                           1            0  0.707107 -0.707107
#
#        day_of_week_sin  day_of_week_cos  month_sin     month_cos  \
# 1428         -0.433884        -0.900969  -0.866025 -5.000000e-01
# 1429         -0.974928        -0.222521  -0.866025 -5.000000e-01
# 1430          0.974928        -0.222521  -1.000000 -1.836970e-16
# 1431          0.433884        -0.900969  -1.000000 -1.836970e-16
# 1432          0.433884        -0.900969  -1.000000 -1.836970e-16
# ...                ...              ...        ...           ...
# 58128         0.781831         0.623490  -0.500000  8.660254e-01
# 58129        -0.974928        -0.222521   0.000000  1.000000e+00
# 58130        -0.433884        -0.900969  -1.000000 -1.836970e-16
# 58131        -0.433884        -0.900969  -0.500000  8.660254e-01
# 58132        -0.974928        -0.222521  -0.500000  8.660254e-01
#
#        day_of_year_sin  day_of_year_cos
# 1428         -0.953681        -0.300820
# 1429         -0.998880        -0.047321
# 1430         -0.999769         0.021516
# 1431         -0.999250         0.038722
# 1432         -0.999250         0.038722
# ...                ...              ...
# 58128        -0.478734         0.877960
# 58129         0.188227         0.982126
# 58130        -0.999250         0.038722
# 58131        -0.205104         0.978740
# 58132        -0.188227         0.982126
#
# [79629 rows x 55 columns]

# %%
data['precip_intensity_probability'] = data.precipIntensity * data.precipProbability

# %%
data.columns
# Out:
# Index(['x', 'y', 'timestamp', 'date', 'month', 'day', 'day_of_year',
#        'day_of_week', 'hour', 'address', 'severity', 'accident_type',
#        'severity_numeric', 'borough', 'cluster_id', 'sample_type',
#        'borough_id', 'area_km2', 'population', 'population_density',
#        'timestamp_darksky', 'icon', 'precipIntensity', 'precipProbability',
#        'temperature', 'apparentTemperature', 'dewPoint', 'humidity',
#        'windSpeed', 'cloudCover', 'uvIndex', 'visibility', 'windBearing',
#        'windGust', 'pressure', 'precipType', 'ozone', 'summary_Clear',
#        'summary_Foggy', 'summary_Heavy Rain', 'summary_Light Rain',
#        'summary_Mostly Cloudy', 'summary_Overcast', 'summary_Partly Cloudy',
#        'summary_Possible Drizzle', 'summary_Possible Light Rain',
#        'summary_Rain', 'hour_sin', 'hour_cos', 'day_of_week_sin',
#        'day_of_week_cos', 'month_sin', 'month_cos', 'day_of_year_sin',
#        'day_of_year_cos', 'precip_intensity_probability'],
#       dtype='object')

# %%
cols_to_keep = ['x', 'y', 'cluster_id', 'sample_type',
       'area_km2', 'population', 'population_density',
       'precipIntensity', 'precipProbability', 'temperature',
       'apparentTemperature', 'dewPoint', 'humidity', 'windSpeed',
       'cloudCover', 'uvIndex', 'visibility',
       'pressure', 'ozone', 'summary_Clear', 'summary_Foggy',
       'summary_Heavy Rain', 'summary_Light Rain', 'summary_Mostly Cloudy',
       'summary_Overcast', 'summary_Partly Cloudy', 'summary_Possible Drizzle',
       'summary_Possible Light Rain', 'summary_Rain', 'hour_sin', 'hour_cos',
       'day_of_week_sin', 'day_of_week_cos', 'month_sin', 'month_cos',
       'day_of_year_sin', 'day_of_year_cos', 'precip_intensity_probability']
data = data[cols_to_keep]

# %%
numeric_features = ['x', 'y', 'population_density',
       'precip_intensity_probability', 'temperature',
       'dewPoint', 'humidity', 'windSpeed',
       'cloudCover', 'uvIndex', 'visibility',
       'pressure', 'ozone','hour_sin', 'hour_cos',
       'day_of_week_sin', 'day_of_week_cos', 
       'month_sin', 'month_cos',
       'day_of_year_sin', 'day_of_year_cos']

# categorical_features = ['cluster_id']

ohe_weather_features = ['summary_Clear', 'summary_Foggy',
       'summary_Heavy Rain', 'summary_Light Rain', 'summary_Mostly Cloudy',
       'summary_Overcast', 'summary_Partly Cloudy', 'summary_Possible Drizzle',
       'summary_Possible Light Rain', 'summary_Rain']
       
# ohe_borough_features = ['borough_ANTONIO NARIÑO',
#        'borough_BARRIOS UNIDOS', 'borough_BOSA', 'borough_CANDELARIA',
#        'borough_CHAPINERO', 'borough_CIUDAD BOLIVAR', 'borough_ENGATIVA',
#        'borough_FONTIBON', 'borough_KENNEDY', 'borough_LOS MARTIRES',
#        'borough_PUENTE ARANDA', 'borough_RAFAEL URIBE URIBE',
#        'borough_SAN CRISTOBAL', 'borough_SANTA FE', 'borough_SUBA',
#        'borough_SUMAPAZ', 'borough_TEUSAQUILLO', 'borough_TUNJUELITO',
#        'borough_USAQUEN', 'borough_USME']

target_feature = ['sample_type']

# %% [markdown]
# ## Numeric feature scaling

# %%
data_numeric = data[numeric_features]
data_numeric.head(2)
# Out:
#               x         y  population_density  precip_intensity_probability  \
# 1428 -74.154268  4.622942            28205.31                      0.087780
# 1429 -74.051403  4.722273            12117.27                      0.016709
#
#       temperature  dewPoint  humidity  windSpeed  cloudCover  uvIndex  ...  \
# 1428        14.62     12.92      0.90       1.48        0.74      5.0  ...
# 1429        19.41     12.60      0.65       2.33        0.71      8.0  ...
#
#       pressure  ozone  hour_sin  hour_cos  day_of_week_sin  day_of_week_cos  \
# 1428    1015.4  268.4 -0.500000 -0.866025        -0.433884        -0.900969
# 1429    1013.1  266.2 -0.707107 -0.707107        -0.974928        -0.222521
#
#       month_sin  month_cos  day_of_year_sin  day_of_year_cos
# 1428  -0.866025       -0.5        -0.953681        -0.300820
# 1429  -0.866025       -0.5        -0.998880        -0.047321
#
# [2 rows x 21 columns]

# %%
scaled_features = StandardScaler().fit_transform(data_numeric.values)
scaled_features_df = pd.DataFrame(scaled_features, index=data_numeric.index, columns=data_numeric.columns)
scaled_features_df
# Out:
#               x         y  population_density  precip_intensity_probability  \
# 1428  -1.303188 -0.472485            1.481885                     -0.332505
# 1429   1.291098  1.310883           -0.420427                     -0.530094
# 1430   0.195069 -1.417821           -0.878419                     -0.301412
# 1431   0.343510  1.279385           -0.420427                     -0.574231
# 1432   0.746928  0.710758           -0.420427                     -0.574231
# ...         ...       ...                 ...                           ...
# 58128 -0.834559 -1.229071            0.526333                     -0.361294
# 58129  0.462069 -1.057263           -1.565142                      1.716517
# 58130  0.122174 -0.532760           -0.088873                     -0.272087
# 58131 -1.806306 -1.310916           -1.209638                      0.671935
# 58132  0.901288 -0.230302           -1.420224                     -0.224613
#
#        temperature  dewPoint  humidity  windSpeed  cloudCover   uvIndex  ...  \
# 1428      0.266373  0.976048  0.656771  -0.679009   -0.409249  0.690870  ...
# 1429      1.803363  0.839213 -1.476156   0.473268   -0.586550  1.639217  ...
# 1430     -1.517691 -0.708728  1.424624  -0.923020   -0.054646 -0.889708  ...
# 1431     -0.487683  0.253390  0.912722  -0.909464    0.772759 -0.573593  ...
# 1432     -0.487683  0.253390  0.912722  -0.909464    0.772759 -0.573593  ...
# ...            ...       ...       ...        ...         ...       ...  ...
# 58128     1.723144 -0.020279 -2.073375   0.066582   -1.000253  1.955333  ...
# 58129    -0.850271 -0.336709  0.827405  -1.275482    0.713659 -0.889708  ...
# 58130     1.081395  0.706655 -0.793619   0.324150   -0.054646  1.639217  ...
# 58131     0.757311  1.412208  0.400819   0.256369    0.359056  1.006986  ...
# 58132    -1.241739 -0.781421  0.912722  -0.733234   -0.172847 -0.889708  ...
#
#        pressure     ozone  hour_sin  hour_cos  day_of_week_sin  \
# 1428  -0.236849  1.756544 -0.560156 -0.935940        -0.665850
# 1429  -1.164030  1.520226 -0.845133 -0.677922        -1.434435
# 1430   0.166273  1.702835  0.815833 -0.935940         1.335447
# 1431   0.287210  1.509484  0.483970 -1.098137         0.566863
# 1432   0.287210  1.509484  0.483970 -1.098137         0.566863
# ...         ...       ...       ...       ...              ...
# 58128 -0.559347 -1.197429 -1.063803 -0.341665         1.061143
# 58129  0.609708 -1.444489  1.319480  1.281923        -1.434435
# 58130  0.166273  0.768305 -1.063803 -0.341665        -0.665850
# 58131 -1.526840 -2.067508 -1.201265  0.890344        -0.665850
# 58132 -0.115912 -2.142700  1.100809 -0.677922        -1.434435
#
#        day_of_week_cos  month_sin  month_cos  day_of_year_sin  day_of_year_cos
# 1428         -1.203199  -0.923700  -0.802728        -1.082102        -0.571543
# 1429         -0.244487  -0.923700  -0.802728        -1.145696        -0.195190
# 1430         -0.244487  -1.110443  -0.051325        -1.146946        -0.092991
# 1431         -1.203199  -1.110443  -0.051325        -1.146217        -0.067447
# 1432         -1.203199  -1.110443  -0.051325        -1.146217        -0.067447
# ...                ...        ...        ...              ...              ...
# 58128         0.951008  -0.413508   1.250143        -0.413862         1.178515
# 58129        -0.244487   0.283427   1.451481         0.524538         1.333163
# 58130        -1.203199  -1.110443  -0.051325        -1.146217        -0.067447
# 58131        -1.203199  -0.413508   1.250143        -0.028871         1.328137
# 58132        -0.244487  -0.413508   1.250143        -0.005124         1.333163
#
# [79629 rows x 21 columns]

# %%
scaled_features1 = MinMaxScaler(feature_range=(-1,1)).fit_transform(data_numeric.values)
scaled_features_df_1 = pd.DataFrame(scaled_features1, index=data_numeric.index, columns=data_numeric.columns)
scaled_features_df_1
# Out:
#               x         y  population_density  precip_intensity_probability  \
# 1428   0.189165  0.526393            1.000000                     -0.982737
# 1429   0.772001  0.764204           -0.141119                     -0.996714
# 1430   0.525765  0.400333           -0.415850                     -0.980537
# 1431   0.559114  0.760004           -0.141119                     -0.999836
# 1432   0.649747  0.684178           -0.141119                     -0.999836
# ...         ...       ...                 ...                           ...
# 58128  0.294448  0.425503            0.426803                     -0.984773
# 58129  0.585750  0.448413           -0.827787                     -0.837789
# 58130  0.509389  0.518355            0.057766                     -0.978463
# 58131  0.076133  0.414589           -0.614535                     -0.911683
# 58132  0.684426  0.558688           -0.740857                     -0.975104
#
#        temperature  dewPoint  humidity  windSpeed  cloudCover   uvIndex  ...  \
# 1428      0.120037  0.503178  0.710145  -0.678019    0.469388 -0.285714  ...
# 1429      0.567492  0.469280 -0.014493  -0.414861    0.408163  0.142857  ...
# 1430     -0.399346  0.085805  0.971014  -0.733746    0.591837 -1.000000  ...
# 1431     -0.099486  0.324153  0.797101  -0.730650    0.877551 -0.857143  ...
# 1432     -0.099486  0.324153  0.797101  -0.730650    0.877551 -0.857143  ...
# ...            ...       ...       ...        ...         ...       ...  ...
# 58128     0.544138  0.256356 -0.217391  -0.507740    0.265306  0.285714  ...
# 58129    -0.205044  0.177966  0.768116  -0.814241    0.857143 -1.000000  ...
# 58130     0.357310  0.436441  0.217391  -0.448916    0.591837  0.142857  ...
# 58131     0.262961  0.611229  0.623188  -0.464396    0.734694 -0.142857  ...
# 58132    -0.319010  0.067797  0.797101  -0.690402    0.551020 -1.000000  ...
#
#        pressure     ozone  hour_sin  hour_cos  day_of_week_sin  \
# 1428   0.093750  0.618519 -0.500000 -0.866025        -0.445042
# 1429  -0.145833  0.537037 -0.707107 -0.707107        -1.000000
# 1430   0.197917  0.600000  0.500000 -0.866025         1.000000
# 1431   0.229167  0.533333  0.258819 -0.965926         0.445042
# 1432   0.229167  0.533333  0.258819 -0.965926         0.445042
# ...         ...       ...       ...       ...              ...
# 58128  0.010417 -0.400000 -0.866025 -0.500000         0.801938
# 58129  0.312500 -0.485185  0.866025  0.500000        -1.000000
# 58130  0.197917  0.277778 -0.866025 -0.500000        -0.445042
# 58131 -0.239583 -0.700000 -0.965926  0.258819        -0.445042
# 58132  0.125000 -0.725926  0.707107 -0.707107        -1.000000
#
#        day_of_week_cos  month_sin     month_cos  day_of_year_sin  \
# 1428         -1.000000  -0.866025 -5.000000e-01        -0.953690
# 1429         -0.286208  -0.866025 -5.000000e-01        -0.998889
# 1430         -0.286208  -1.000000 -1.836970e-16        -0.999778
# 1431         -1.000000  -1.000000 -1.836970e-16        -0.999259
# 1432         -1.000000  -1.000000 -1.836970e-16        -0.999259
# ...                ...        ...           ...              ...
# 58128         0.603875  -0.500000  8.660254e-01        -0.478738
# 58129        -0.286208   0.000000  1.000000e+00         0.188228
# 58130        -1.000000  -1.000000 -1.836970e-16        -0.999259
# 58131        -1.000000  -0.500000  8.660254e-01        -0.205106
# 58132        -0.286208  -0.500000  8.660254e-01        -0.188228
#
#        day_of_year_cos
# 1428         -0.300844
# 1429         -0.047341
# 1430          0.021498
# 1431          0.038704
# 1432          0.038704
# ...                ...
# 58128         0.877958
# 58129         0.982125
# 58130         0.038704
# 58131         0.978740
# 58132         0.982125
#
# [79629 rows x 21 columns]

# %% [markdown]
# ## Model 1

# %% [markdown]
# ### Numeric variables

# %%
scaled_features_ohe_weather_df = scaled_features_df_1.join(data[ohe_weather_features])

# %%
X_train_3, X_test_val_3, y_train_3, y_test_val_3 = train_test_split(scaled_features_ohe_weather_df, data[target_feature], test_size=0.33, random_state = 42)
X_test_3, X_val_3, y_test_3, y_val_3 = train_test_split(X_test_val_3, y_test_val_3, test_size=0.33, random_state = 42)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-8a4e51ecacef> in <module>
# ----> 1 X_train_3, X_test_val_3, y_train_3, y_test_val_3 = train_test_split(scaled_features_ohe_weather_df, data[target_feature], test_size=0.33, random_state = 42)
#       2 X_test_3, X_val_3, y_test_3, y_val_3 = train_test_split(X_test_val_3, y_test_val_3, test_size=0.33, random_state = 42)
#
# ~/anaconda3/envs/ds4a-project/lib/python3.8/site-packages/sklearn/model_selection/_split.py in train_test_split(*arrays, **options)
#    2116         raise TypeError("Invalid parameters passed: %s" % str(options))
#    2117
# -> 2118     arrays = indexable(*arrays)
#    2119
#    2120     n_samples = _num_samples(arrays[0])
#
# ~/anaconda3/envs/ds4a-project/lib/python3.8/site-packages/sklearn/utils/validation.py in indexable(*iterables)
#     246     """
#     247     result = [_make_indexable(X) for X in iterables]
# --> 248     check_consistent_length(*result)
#     249     return result
#     250
#
# ~/anaconda3/envs/ds4a-project/lib/python3.8/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     209     uniques = np.unique(lengths)
#     210     if len(uniques) > 1:
# --> 211         raise ValueError("Found input variables with inconsistent numbers of"
#     212                          " samples: %r" % [int(l) for l in lengths])
#     213
#
# ValueError: Found input variables with inconsistent numbers of samples: [114125, 79629]

# %%
# %%time
clf = RandomForestClassifier(n_estimators=200, max_leaf_nodes=20, min_samples_leaf=4, max_features=15, n_jobs=-1, criterion='entropy')

clf3, y_pred_3, y_pred_proba_3 = model_fit_predict(X_train_3, X_val_3, y_train_3.values.ravel(), y_val_3.values.ravel(), clf)
# Out:
# Weigthed F1 score: 0.57 (+/- 0.004 )
# Cohen kappa score 0.1532
#               precision    recall  f1-score   support
#
# non-accident       0.56      0.80      0.66      4369
#     accident       0.63      0.35      0.45      4303
#
#     accuracy                           0.58      8672
#    macro avg       0.60      0.58      0.55      8672
# weighted avg       0.60      0.58      0.56      8672
#
#                   Random-CV Stratified-CV
# f1                 0.488007      0.484556
# roc_auc            0.633555      0.632741
# average_precision  0.682669      0.683339
# accuracy           0.584806      0.584769
# precision           0.64476      0.640299
# recall             0.393619      0.400246
# CPU times: user 1min 1s, sys: 428 ms, total: 1min 2s
# Wall time: 7min 52s

# %%
model_plot(y_val_3, y_pred_3, y_pred_proba_3, 'Random Forest numerical MinMax')
